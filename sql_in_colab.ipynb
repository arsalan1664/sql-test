# %% [markdown]
# <a href="https://colab.research.google.com/github/arsalan1664/sql-test/blob/main/sql_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DataBase Name = sqlite sakila

# %% [markdown]
# # Question
#
#
#
#
# > How many movies are there in each rating category?
#
#
#
# > What is the total number of movies in each category held in inventory?
#
#
#
# >What is the total number of movies in each category held in inventory?
#
# >Which movies of rating 'PG' are held in highest quantity in the inventory?
#
# > What movies has each actor starred in and who has starred in the most movies?
#
#
#
#
# > Overdue rentals,Payments per rental, payments per date, payments per store

# %%
### Import library ###

import pandas as pd

# %load_ext sql

### Connect to SQlite database ###

# %sql sqlite:////content/sqlite-sakila.sq
# Out:
# 'Connected: @/content/sqlite-sakila.sq'

# %%
# %%sql
# SELECT type, name
# FROM sqlite_master
# WHERE type = 'table';
# Out:
#  * sqlite:////content/sqlite-sakila.sq
# Done.
# [('table', 'actor'),
#  ('table', 'country'),
#  ('table', 'city'),
#  ('table', 'address'),
#  ('table', 'language'),
#  ('table', 'category'),
#  ('table', 'customer'),
#  ('table', 'film'),
#  ('table', 'film_actor'),
#  ('table', 'film_category'),
#  ('table', 'film_text'),
#  ('table', 'inventory'),
#  ('table', 'staff'),
#  ('table', 'store'),
#  ('table', 'payment'),
#  ('table', 'rental')]

# %%
table_actor    =  %sql  SELECT     *      FROM actor ;
table_country  =  %sql  SELECT     *      FROM country ;
table_category =  %sql  SELECT     *      FROM category ;
table_film     =  %sql  SELECT     *      FROM film ;
# Out:
#  * sqlite:////content/sqlite-sakila.sq
# Done.
#  * sqlite:////content/sqlite-sakila.sq
# Done.
#  * sqlite:////content/sqlite-sakila.sq
# Done.
#  * sqlite:////content/sqlite-sakila.sq
# Done.

# %%
# %sql  SELECT     *      FROM country where country_id = 1;
# Out:
#  * sqlite:////content/sqlite-sakila.sq
# Done.
# [(1, 'Afghanistan', '2011-09-14 18:05:01')]

# %%
 # %sql  SELECT   first_name , last_name      FROM actor
# Out:
#  * sqlite:////content/sqlite-sakila.sq
# Done.
# [('PENELOPE', 'GUINESS'),
#  ('NICK', 'WAHLBERG'),
#  ('ED', 'CHASE'),
#  ('JENNIFER', 'DAVIS'),
#  ('JOHNNY', 'LOLLOBRIGIDA'),
#  ('BETTE', 'NICHOLSON'),
#  ('GRACE', 'MOSTEL'),
#  ('MATTHEW', 'JOHANSSON'),
#  ('JOE', 'SWANK'),
#  ('CHRISTIAN', 'GABLE'),
#  ('ZERO', 'CAGE'),
#  ('KARL', 'BERRY'),
#  ('UMA', 'WOOD'),
#  ('VIVIEN', 'BERGEN'),
#  ('CUBA', 'OLIVIER'),
#  ('FRED', 'COSTNER'),
#  ('HELEN', 'VOIGHT'),
#  ('DAN', 'TORN'),
#  ('BOB', 'FAWCETT'),
#  ('LUCILLE', 'TRACY'),
#  ('KIRSTEN', 'PALTROW'),
#  ('ELVIS', 'MARX'),
#  ('SANDRA', 'KILMER'),
#  ('CAMERON', 'STREEP'),
#  ('KEVIN', 'BLOOM'),
#  ('RIP', 'CRAWFORD'),
#  ('JULIA', 'MCQUEEN'),
#  ('WOODY', 'HOFFMAN'),
#  ('ALEC', 'WAYNE'),
#  ('SANDRA', 'PECK'),
#  ('SISSY', 'SOBIESKI'),
#  ('TIM', 'HACKMAN'),
#  ('MILLA', 'PECK'),
#  ('AUDREY', 'OLIVIER'),
#  ('JUDY', 'DEAN'),
#  ('BURT', 'DUKAKIS'),
#  ('VAL', 'BOLGER'),
#  ('TOM', 'MCKELLEN'),
#  ('GOLDIE', 'BRODY'),
# ...

# %%
# %%sql
# SELECT
#     rating AS Rating
#     ,COUNT(title) AS Count
# FROM film
# GROUP BY rating
# ORDER BY Count DESC
# Out:
#  * sqlite:////content/sqlite-sakila.sq
# Done.
# [('PG-13', 223), ('NC-17', 210), ('R', 195), ('PG', 194), ('G', 178)]

# %%
# %%sql
# select
#    count (title)
#    from film
# Out:
#  * sqlite:////content/sqlite-sakila.sq
# Done.
# [(1000,)]

# %%
# %%sql select
#       distinct rating
# from film
# Out:
#  * sqlite:////content/sqlite-sakila.sq
# Done.
# [('PG',), ('G',), ('NC-17',), ('PG-13',), ('R',)]

# %%
# %%sql
# SELECT
#     rating AS Rating
#     ,COUNT(title) AS Count
# FROM film
# Out:
#  * sqlite:////content/sqlite-sakila.sq
# Done.
# [('NC-17', 1000)]

# %%
echo "# sql-test" >> README.md
git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/arsalan1664/sql-test.git
git push -u origin main
# Out:
#   File "<ipython-input-3-adb5a943b04b>", line 1
#     echo "# sql-test" >> README.md
#          ^
# SyntaxError: invalid syntax

# %%
# !git clone https://github.com/arsalan1664/sql-test.git
# Out:
# fatal: destination path 'sql-test' already exists and is not an empty directory.

# %%
git remote add origin https://github.com/arsalan1664/sql-test.git
git branch -M main
git push -u origin main
# Out:
#   File "<ipython-input-7-4dab8f653992>", line 1
#     git remote add origin https://github.com/arsalan1664/sql-test.git
#         ^
# SyntaxError: invalid syntax

# %%
echo "# sql-test" >> README.md
git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/arsalan1664/sql-test.git
git push -u origin main
# Out:
#   File "<ipython-input-5-adb5a943b04b>", line 1
#     echo "# sql-test" >> README.md
#          ^
# SyntaxError: invalid syntax
